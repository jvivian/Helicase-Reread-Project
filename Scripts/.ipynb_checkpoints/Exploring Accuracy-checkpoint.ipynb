# %% [markdown]
# # Exploring Accuracy

# %% [markdown]
#     1. Plot the accuracy of the Label by the BARCODE (by CHUNK score)
#     2. Plot Accuracy of context by the BARCODE
#     3. Plot soft-call accuracy
#     4. Try only states 8,9,10 in accuracy
#     5. Compare reread accuracy from rereads to single reads

# %% [markdown]
# ## Accuracy Plot of Label given the Barcode

# %%
# %matplotlib inline
from IPython.display import display, clear_output
import sys, os, random, argparse
import numpy as np
import Methods
import seaborn as sns

sys.path.append( '../Models' )
from Simple_Model import *

# Acquire Events
source = '../Data/JSON/New/'
for root, dirnames, filenames in os.walk(source):
    events = filenames

# Read in Untrained HMM 
with open ( '../Data/HMMs/TEST.txt', 'r' ) as file:
    model = Model.read( file )

# Acquire indices
indices = { state.name: i for i, state in enumerate( model.states ) }

# Rank Events by CHUNK Score
ranked_events = {}
for i in xrange(10):
    ranked_events[i] = []

print 'Ranking Events by CHUNK Score'
counter = 0
for event_name in events:  
    counter+=1
    # Convert JSON to event
    event = Event.from_json( source + event_name )

    # Convert event into a list of means
    means = [seg['mean'] for seg in event.segments]

    # Perform forward_backward algorithm
    trans, ems = model.forward_backward( means )

    # Partition the event into 'chunks' of context / label regions
    contexts, labels = partition_event( indices, event, ems, means)

    # Get chunk scores
    contexts, labels = chunk_score( indices, contexts, labels, ems )

    # Get chunk vector
    contexts, labels = chunk_vector( indices, contexts, labels, ems )
    
    if contexts and labels:
        max_c = max( [ x[0] for x in contexts ] ) 
        max_l = max( [ x[0] for x in labels ] )
        
        for i in xrange(9,-1,-1):
            if max_c >= i*.10 and max_l >= i*.10:
                clear_output(wait=True)
                print 'C:{}\t\tAssigned:{}\tPercentage:{}%'.format(round(max_c,2), i, round((counter*1.0/len(events))*100,2))
                sys.stdout.flush()
                ranked_events[i].append( (event_name, contexts, labels) )
                break
print '\n'
for i in ranked_events:
    print 'cscore:{} to {}\t# of Events:{}'.format(i*.10, (i+1)*.10, len(ranked_events[i]))

# Create array
data = np.zeros( (10, 12) ) 

## Iterate through the range of cutoff values: 
cscores = [ 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0 ]
data_counter = 0
for cscore in cscores:
   
    # Counters
    counters = []
    counter = 0
    
    # Bins to hold counts
    bins = { 'f': 0, 'l': 0, 'r':0, 'b': 0, 'i': 0, 'h': 0 }                # Counter for hard calls
    soft_calls = { 'f': [], 'l': [], 'r':[], 'b': [], 'i': [], 'h': [] }    # Will hold soft calls
    
    ## For a given cscore, group and iterate through.
    event_sum = 0
    for i in xrange(9, int(cscore*10-1), -1):
        event_sum += len(ranked_events[i])
        for event in ranked_events[i]:
            
            # Unpack Variables
            event_name = event[0]
            contexts = event[1]
            labels = event[2]
            
            barcode = event_name.split('-')[0]
            
            # update counter
            counter += 1
           
            ## Single Read Methods
            fchunk, fcall = Methods.first_chunk( contexts, labels, cscore )
            lchunk, lcall = Methods.last_chunk( contexts, labels, cscore )
            rchunk, rcall = Methods.random_chunk( contexts, labels, cscore )
            
            ## Multi-Read Methods
            bchunk, bcall = Methods.best_chunk( contexts, labels )
            ichunk, icall = Methods.ind_consensus( contexts, labels, cscore )
            hchunk, hcall = Methods.hmm_consensus( indices, ems, len(means), chunk_vector )

             # First Chunk
            soft_calls['f'].append( fchunk )
            if barcode == fcall[1]:
                bins['f'] += 1
                
            # Last Chunk
            soft_calls['l'].append( lchunk )
            if barcode == lcall[1]:
                bins['l'] += 1
                
            # Random Chunk
            soft_calls['r'].append( rchunk )
            if barcode == rcall[1]:
                bins['r'] += 1
            
            # Best Chunk
            soft_calls['b'].append( bchunk )
            if barcode == bcall[1]:
                bins['b'] += 1
                
            # Ind Consensus
            soft_calls['i'].append( ichunk )
            if barcode == icall[1]:
                bins['i'] += 1
                
            #HMM Consensus
            soft_calls['h'].append( hchunk )
            if barcode == hcall[1]:
                bins['h'] += 1
                
    j = data_counter
    data[j][0] = bins['f']*1.0 / counter
    data[j][1] = np.mean(soft_calls['f'])
    data[j][2] = bins['l']*1.0 / counter
    data[j][3] = np.mean(soft_calls['l'])
    data[j][4] = bins['r']*1.0 / counter
    data[j][5] = np.mean(soft_calls['r'])
    data[j][6] = bins['h']*1.0 / counter
    data[j][7] = np.mean(soft_calls['h'])
    data[j][8] = bins['b']*1.0 / counter
    data[j][9] = np.mean(soft_calls['b'])
    data[j][10] = bins['i']*1.0 / counter
    data[j][11] = np.mean(soft_calls['i'])
    data_counter += 1
     

accuracy_by_filter_score( data, 'Label Accuracy by Chunk Score' )
# Out:
# C:0.0		Assigned:0	Percentage:100.0%
# cscore:0.0 to 0.1	# of Events:57
# cscore:0.1 to 0.2	# of Events:0
# cscore:0.2 to 0.3	# of Events:4
# cscore:0.3 to 0.4	# of Events:3
# cscore:0.4 to 0.5	# of Events:5
# cscore:0.5 to 0.6	# of Events:6
# cscore:0.6 to 0.7	# of Events:9
# cscore:0.7 to 0.8	# of Events:4
# cscore:0.8 to 0.9	# of Events:21
# cscore:0.9 to 1.0	# of Events:20

# %% [markdown]
# ## Accuray of Context by Barcode

# %%
data_counter = 0
for cscore in cscores:
    print '\nCscore:{}\n'.format(cscore)
   
    # Counters
    counters = []
    counter = 0
    
    # Bins to hold counts
    bins = { 'f': 0, 'l': 0, 'r':0, 'b': 0, 'i': 0, 'h': 0 }                # Counter for hard calls
    soft_calls = { 'f': [], 'l': [], 'r':[], 'b': [], 'i': [], 'h': [] }    # Will hold soft calls
    
    ## For a given cscore, group and iterate through.
    event_sum = 0
    for i in xrange(9, int(cscore*10-1), -1):
        event_sum += len(ranked_events[i])
        for event in ranked_events[i]:
            
            # Unpack Variables
            event_name = event[0]
            contexts = event[1]
            labels = event[2]
            
            barcode = event_name.split('-')[0]
            
            # update counter
            counter += 1
           
            ## Single Read Methods
            fchunk, fcall = Methods.first_chunk( contexts, labels, cscore )
            lchunk, lcall = Methods.last_chunk( contexts, labels, cscore )
            rchunk, rcall = Methods.random_chunk( contexts, labels, cscore )
            
            ## Multi-Read Methods
            bchunk, bcall = Methods.best_chunk( contexts, labels )
            ichunk, icall = Methods.ind_consensus( contexts, labels, cscore )
            hchunk, hcall = Methods.hmm_consensus( indices, ems, len(means), chunk_vector )

             # First Chunk
            soft_calls['f'].append( fchunk )
            if barcode == fcall[0]:
                bins['f'] += 1
                
            # Last Chunk
            soft_calls['l'].append( lchunk )
            if barcode == lcall[0]:
                bins['l'] += 1
                
            # Random Chunk
            soft_calls['r'].append( rchunk )
            if barcode == rcall[0]:
                bins['r'] += 1
            
            # Best Chunk
            soft_calls['b'].append( bchunk )
            if barcode == bcall[0]:
                bins['b'] += 1
                
            # Ind Consensus
            soft_calls['i'].append( ichunk )
            if barcode == icall[0]:
                bins['i'] += 1
            print 'Context_hc: {}\tBarcode: {}\tEvent_Name:{}'.format( icall[0], barcode, event_name )
                
            #HMM Consensus
            soft_calls['h'].append( hchunk )
            if barcode == hcall[0]:
                bins['h'] += 1
                
    j = data_counter
    data[j][0] = bins['f']*1.0 / counter
    data[j][1] = np.mean(soft_calls['f'])
    data[j][2] = bins['l']*1.0 / counter
    data[j][3] = np.mean(soft_calls['l'])
    data[j][4] = bins['r']*1.0 / counter
    data[j][5] = np.mean(soft_calls['r'])
    data[j][6] = bins['h']*1.0 / counter
    data[j][7] = np.mean(soft_calls['h'])
    data[j][8] = bins['b']*1.0 / counter
    data[j][9] = np.mean(soft_calls['b'])
    data[j][10] = bins['i']*1.0 / counter
    data[j][11] = np.mean(soft_calls['i'])
    data_counter += 1
# Out:
# Cscore:0.9
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
#
# Cscore:0.8
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
#
# Cscore:0.7
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
#
# Cscore:0.6
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: C	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
#
# Cscore:0.5
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: C	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-468.1.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-401.99.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-297.04.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-310.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-447.68.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-150.06.json
#
# Cscore:0.4
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: C	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-468.1.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-401.99.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-297.04.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-310.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-447.68.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-150.06.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-696.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-352.6.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14710006-12.04.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-34.54.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14708005-329.98.json
#
# Cscore:0.3
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: C	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-468.1.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-401.99.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-297.04.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-310.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-447.68.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-150.06.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-696.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-352.6.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14710006-12.04.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-34.54.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14708005-329.98.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710005-465.82.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14710001-93.01.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-73.25.json
#
# Cscore:0.2
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: C	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-468.1.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-401.99.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-297.04.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-310.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-447.68.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-150.06.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-696.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-352.6.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14710006-12.04.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-34.54.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14708005-329.98.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710005-465.82.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14710001-93.01.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-73.25.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-38.58.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-94.48.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14703001-259.09.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14707006.abf-8.31.json
#
# Cscore:0.1
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: C	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-468.1.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-401.99.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-297.04.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-310.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-447.68.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-150.06.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-696.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-352.6.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14710006-12.04.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-34.54.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14708005-329.98.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710005-465.82.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14710001-93.01.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-73.25.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-38.58.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-94.48.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14703001-259.09.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14707006.abf-8.31.json
#
# Cscore:0.0
#
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-10.74.json
# Context_hc: C	Barcode: C	Event_Name:C-14702003-105.49.json
# Context_hc: C	Barcode: C	Event_Name:C-14710001-438.95.json
# Context_hc: C	Barcode: C	Event_Name:C-14718008-239.18.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-732.7.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-131.34.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721004-48.62.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721004-617.34.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721007-190.08.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721007-515.97.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-675.51.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721008-290.56.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-577.13.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-108.84.json
# Context_hc: C	Barcode: C	Event_Name:C-14722002-263.88.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-575.05.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-591.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-475.58.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-491.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-482.56.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-321.35.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-487.41.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-613.62.json
# Context_hc: C	Barcode: C	Event_Name:C-14722001-640.37.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-11.28.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-563.38.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710002-123.32.json
# Context_hc: mC	Barcode: hmC	Event_Name:hmC-14710002-456.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-368.82.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-89.48.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-679.14.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-3.35.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14710001-518.09.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724002-130.98.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-473.12.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14724004-378.82.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724007-201.88.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729001-432.9.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-175.21.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-629.63.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-287.91.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-231.88.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-331.19.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14714002-69.03.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-2.86.json
# Context_hc: C	Barcode: C	Event_Name:C-14710005-11.53.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721003-652.38.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721009-216.09.json
# Context_hc: mC	Barcode: C	Event_Name:C-14721010-331.17.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-461.04.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-552.42.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-415.59.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731002-135.75.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-437.56.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714002-468.1.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-401.99.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-297.04.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14729003-310.76.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729003-447.68.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-150.06.json
# Context_hc: C	Barcode: C	Event_Name:C-14721007-696.53.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-352.6.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14710006-12.04.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-34.54.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14708005-329.98.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710005-465.82.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14710001-93.01.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729002-73.25.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-38.58.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-94.48.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14703001-259.09.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14707006.abf-8.31.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-522.19.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702001-68.01.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-133.06.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14702003-7.39.json
# Context_hc: C	Barcode: C	Event_Name:C-14708002-598.96.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14710001-145.04.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14710002-622.03.json
# Context_hc: mC	Barcode: C	Event_Name:C-14718008-274.15.json
# Context_hc: mC	Barcode: C	Event_Name:C-14718009-172.0.json
# Context_hc: C	Barcode: C	Event_Name:C-14718010-430.51.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721001-146.12.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721001-282.77.json
# Context_hc: C	Barcode: C	Event_Name:C-14721001-378.31.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-35.16.json
# Context_hc: C	Barcode: C	Event_Name:C-14721003-522.79.json
# Context_hc: C	Barcode: C	Event_Name:C-14721004-151.42.json
# Context_hc: C	Barcode: C	Event_Name:C-14721008-401.01.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14721009-187.82.json
# Context_hc: C	Barcode: C	Event_Name:C-14721010-552.54.json
# Context_hc: C	Barcode: C	Event_Name:C-14721014-165.32.json
# Context_hc: hmC	Barcode: C	Event_Name:C-14722001-568.99.json
# Context_hc: C	Barcode: C	Event_Name:C-14722003-374.23.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-282.0.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-584.02.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14707001.abf-640.07.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14708005-666.03.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-281.33.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710001-311.6.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14710003-35.58.json
# Context_hc: C	Barcode: hmC	Event_Name:hmC-14731001-219.76.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-361.23.json
# Context_hc: hmC	Barcode: hmC	Event_Name:hmC-14731001-407.61.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14703002-363.19.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14703002-501.09.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14703002-557.89.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14703002-75.76.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-134.61.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-172.68.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14707004.abf-272.04.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-538.35.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707004.abf-746.12.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14707005.abf-161.86.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14708002-272.37.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14708005-54.6.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14708006-40.97.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14710002-320.09.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14714003-120.78.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724001-745.92.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14724003-439.63.json
# Context_hc: hmC	Barcode: mC	Event_Name:mC-14724006-319.19.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14725001-205.01.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14729002-706.61.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729003-8.95.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14729004-167.3.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14730001-116.55.json
# Context_hc: mC	Barcode: mC	Event_Name:mC-14730001-510.66.json
# Context_hc: C	Barcode: mC	Event_Name:mC-14730002-324.5.json

# %%
accuracy_by_filter_score( data, 'Accuracy of Context Chunk by Barcode -- Old "Test HMM"' )

# %% [markdown]
# ## Plot Soft-Call Accuracy

# %%
accuracy_by_filter_score( data, 'Soft-Call Accuracy of Context by Barcode', sc=True )

# %% [markdown]
# ## Compare Reread Accuracy between Single Reads and Rereads

# %%
# Rank Events by CHUNK Score
ranked_events = {}
for i in xrange(10):
    ranked_events[i] = []

print 'Ranking Events by CHUNK Score'
counter = 0
for event_name in events:  
    counter+=1
    # Convert JSON to event
    event = Event.from_json( source + event_name )

    # Convert event into a list of means
    means = [seg['mean'] for seg in event.segments]

    # Perform forward_backward algorithm
    trans, ems = model.forward_backward( means )

    # Partition the event into 'chunks' of context / label regions
    contexts, labels = partition_event( indices, event, ems, means)

    # Get chunk scores
    contexts, labels = chunk_score( indices, contexts, labels, ems )

    # Get chunk vector
    contexts, labels = chunk_vector( indices, contexts, labels, ems )
    
    if contexts and labels:
        max_c = max( [ x[0] for x in contexts ] ) 
        max_l = max( [ x[0] for x in labels ] )
        
        for i in xrange(9,-1,-1):
            if max_c >= i*.10 and max_l >= i*.10:
                C = [ x for x in contexts if x[0] >= i*.10 ]
                L = [ x for x in labels if x[0] >= i*.10 ]
                clear_output(wait=True)
                print 'C:{}\t\tAssigned:{}\tPercentage:{}%'.format(round(max_c,2), i, round((counter*1.0/len(events))*100,2))
                sys.stdout.flush()
                if len(C) > 1:
                    multi=True
                    ranked_events[i].append( (event_name, contexts, labels, multi) )
                else:
                    multi=False
                    ranked_events[i].append( (event_name, contexts, labels, multi) )
                break
#print '\n'
#for i in ranked_events:
    #print 'cscore:{} to {}\t# of Events:{}'.format(i*.10, (i+1)*.10, len(ranked_events[i]))

# Create array
#data_sr =  
#data_mr = )
data = { 'data_sr': np.zeros( (10, 12) ), 'data_mr': np.zeros( (10, 12) ) }

## Iterate through the range of cutoff values: 
cscores = [ 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0 ]
data_counter = 0
for cscore in cscores:
   
    # Counters
    counters = []
    counter_mr = 0
    counter_sr = 0
    
    # Bins to hold counts
    bins_sr = { 'f': 0, 'l': 0, 'r':0, 'b': 0, 'i': 0, 'h': 0 }
    bins_mr = { 'f': 0, 'l': 0, 'r':0, 'b': 0, 'i': 0, 'h': 0 } # Counter for hard calls
    soft_calls = { 'f': [], 'l': [], 'r':[], 'b': [], 'i': [], 'h': [] }    # Will hold soft calls
    
    ## For a given cscore, group and iterate through.
    event_sum = 0
    for i in xrange(9, int(cscore*10-1), -1):
        event_sum += len(ranked_events[i])
        for event in ranked_events[i]:
            
            # Unpack Variables
            event_name = event[0]
            contexts = event[1]
            labels = event[2]
            multi = event[3]
            
            barcode = event_name.split('-')[0]
           
            def run_methods(bins):
            
                ## Single Read Methods
                fchunk, fcall = Methods.first_chunk( contexts, labels, cscore )
                lchunk, lcall = Methods.last_chunk( contexts, labels, cscore )
                rchunk, rcall = Methods.random_chunk( contexts, labels, cscore )

                ## Multi-Read Methods
                bchunk, bcall = Methods.best_chunk( contexts, labels )
                ichunk, icall = Methods.ind_consensus( contexts, labels, cscore )
                hchunk, hcall = Methods.hmm_consensus( indices, ems, len(means), chunk_vector )

                 # First Chunk
                soft_calls['f'].append( fchunk )
                if barcode == fcall[0]:
                    bins['f'] += 1

                # Last Chunk
                soft_calls['l'].append( lchunk )
                if barcode == lcall[0]:
                    bins['l'] += 1

                # Random Chunk
                soft_calls['r'].append( rchunk )
                if barcode == rcall[0]:
                    bins['r'] += 1

                # Best Chunk
                soft_calls['b'].append( bchunk )
                if barcode == bcall[0]:
                    bins['b'] += 1

                # Ind Consensus
                soft_calls['i'].append( ichunk )
                if barcode == icall[0]:
                    bins['i'] += 1

                #HMM Consensus
                soft_calls['h'].append( hchunk )
                if barcode == hcall[0]:
                    bins['h'] += 1
                    
            if multi:
                run_methods(bins_mr)
                # update counter
                counter_mr += 1
            else:
                run_methods(bins_sr)
                counter_sr += 1
    
    print '# of MR events:{}\t# of SR events:{}\tcsore:{}'.format( counter_mr, counter_sr, cscore )
    j = data_counter
    for i in data:
        if i == 'data_mr':
            data[i][j][0] = bins_mr['f']*1.0 / counter_mr
            data[i][j][1] = np.mean(soft_calls['f'])
            data[i][j][2] = bins_mr['l']*1.0 / counter_mr
            data[i][j][3] = np.mean(soft_calls['l'])
            data[i][j][4] = bins_mr['r']*1.0 / counter_mr
            data[i][j][5] = np.mean(soft_calls['r'])
            data[i][j][6] = bins_mr['h']*1.0 / counter_mr
            data[i][j][7] = np.mean(soft_calls['h'])
            data[i][j][8] = bins_mr['b']*1.0 / counter_mr
            data[i][j][9] = np.mean(soft_calls['b'])
            data[i][j][10] = bins_mr['i']*1.0 / counter_mr
            data[i][j][11] = np.mean(soft_calls['i'])
        else:
            data[i][j][0] = bins_sr['f']*1.0 / counter_sr
            data[i][j][1] = np.mean(soft_calls['f'])
            data[i][j][2] = bins_sr['l']*1.0 / counter_sr
            data[i][j][3] = np.mean(soft_calls['l'])
            data[i][j][4] = bins_sr['r']*1.0 / counter_sr
            data[i][j][5] = np.mean(soft_calls['r'])
            data[i][j][6] = bins_sr['h']*1.0 / counter_sr
            data[i][j][7] = np.mean(soft_calls['h'])
            data[i][j][8] = bins_sr['b']*1.0 / counter_sr
            data[i][j][9] = np.mean(soft_calls['b'])
            data[i][j][10] = bins_sr['i']*1.0 / counter_sr
            data[i][j][11] = np.mean(soft_calls['i'])
    data_counter += 1

accuracy_by_filter_score( data['data_sr'], 'Accuracy of Single Reads by Barcode' )
accuracy_by_filter_score( data['data_mr'], 'Accuracy of Multi Reads by Barcode' )
# Out:
# C:0.0		Assigned:0	Percentage:100.0%
# # of MR events:5	# of SR events:16	csore:0.9
# # of MR events:11	# of SR events:37	csore:0.8
# # of MR events:12	# of SR events:47	csore:0.7
# # of MR events:14	# of SR events:56	csore:0.6
# # of MR events:16	# of SR events:59	csore:0.5
# # of MR events:16	# of SR events:64	csore:0.4
# # of MR events:16	# of SR events:65	csore:0.3
# # of MR events:17	# of SR events:66	csore:0.2
# # of MR events:17	# of SR events:68	csore:0.1
# # of MR events:55	# of SR events:74	csore:0.0

# %% [markdown]
# ## Extras:  New Improvements to Pseudo-Trained Model

# %%
# Acquire Events
source = '../Data/JSON/New/'
for root, dirnames, filenames in os.walk(source):
    events = filenames

# Read in Untrained HMM 
with open ( '../Data/HMMs/Temp_Test.txt', 'r' ) as file:
    model = Model.read( file )

# Acquire indices
indices = { state.name: i for i, state in enumerate( model.states ) }

# Rank Events by CHUNK Score
ranked_events = {}
for i in xrange(10):
    ranked_events[i] = []

print 'Ranking Events by CHUNK Score'
counter = 0
for event_name in events:  
    counter+=1
    # Convert JSON to event
    event = Event.from_json( source + event_name )

    # Convert event into a list of means
    means = [seg['mean'] for seg in event.segments]

    # Perform forward_backward algorithm
    trans, ems = model.forward_backward( means )

    # Partition the event into 'chunks' of context / label regions
    contexts, labels = partition_event( indices, event, ems, means)

    # Get chunk scores
    contexts, labels = chunk_score( indices, contexts, labels, ems )

    # Get chunk vector
    contexts, labels = chunk_vector( indices, contexts, labels, ems )
    
    if contexts and labels:
        max_c = max( [ x[0] for x in contexts ] ) 
        max_l = max( [ x[0] for x in labels ] )
        
        for i in xrange(9,-1,-1):
            if max_c >= i*.10 and max_l >= i*.10:
                clear_output(wait=True)
                print 'C:{}\t\tAssigned:{}\tPercentage:{}%'.format(round(max_c,2), i, round((counter*1.0/len(events))*100,2))
                sys.stdout.flush()
                ranked_events[i].append( (event_name, contexts, labels) )
                break
print '\n'
for i in ranked_events:
    print 'cscore:{} to {}\t# of Events:{}'.format(i*.10, (i+1)*.10, len(ranked_events[i]))

# Create array
data = np.zeros( (10, 12) ) 

## Iterate through the range of cutoff values: 
cscores = [ 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0 ]
data_counter = 0
for cscore in cscores:
   
    # Counters
    counters = []
    counter = 0
    
    # Bins to hold counts
    bins = { 'f': 0, 'l': 0, 'r':0, 'b': 0, 'i': 0, 'h': 0 }                # Counter for hard calls
    soft_calls = { 'f': [], 'l': [], 'r':[], 'b': [], 'i': [], 'h': [] }    # Will hold soft calls
    
    ## For a given cscore, group and iterate through.
    event_sum = 0
    for i in xrange(9, int(cscore*10-1), -1):
        event_sum += len(ranked_events[i])
        for event in ranked_events[i]:
            
            # Unpack Variables
            event_name = event[0]
            contexts = event[1]
            labels = event[2]
            
            barcode = event_name.split('-')[0]
            
            # update counter
            counter += 1
           
            ## Single Read Methods
            fchunk, fcall = Methods.first_chunk( contexts, labels, cscore )
            lchunk, lcall = Methods.last_chunk( contexts, labels, cscore )
            rchunk, rcall = Methods.random_chunk( contexts, labels, cscore )
            
            ## Multi-Read Methods
            bchunk, bcall = Methods.best_chunk( contexts, labels )
            ichunk, icall = Methods.ind_consensus( contexts, labels, cscore )
            hchunk, hcall = Methods.hmm_consensus( indices, ems, len(means), chunk_vector )

             # First Chunk
            soft_calls['f'].append( fchunk )
            if barcode == fcall[0]:
                bins['f'] += 1
                
            # Last Chunk
            soft_calls['l'].append( lchunk )
            if barcode == lcall[0]:
                bins['l'] += 1
                
            # Random Chunk
            soft_calls['r'].append( rchunk )
            if barcode == rcall[0]:
                bins['r'] += 1
            
            # Best Chunk
            soft_calls['b'].append( bchunk )
            if barcode == bcall[0]:
                bins['b'] += 1
                
            # Ind Consensus
            soft_calls['i'].append( ichunk )
            if barcode == icall[0]:
                bins['i'] += 1
            print 'Context_hc: {}\tBarcode: {}\tEvent_Name:{}'.format( icall[0], barcode, event_name )
                
            #HMM Consensus
            soft_calls['h'].append( hchunk )
            if barcode == hcall[0]:
                bins['h'] += 1
                
    j = data_counter
    data[j][0] = bins['f']*1.0 / counter
    data[j][1] = np.mean(soft_calls['f'])
    data[j][2] = bins['l']*1.0 / counter
    data[j][3] = np.mean(soft_calls['l'])
    data[j][4] = bins['r']*1.0 / counter
    data[j][5] = np.mean(soft_calls['r'])
    data[j][6] = bins['h']*1.0 / counter
    data[j][7] = np.mean(soft_calls['h'])
    data[j][8] = bins['b']*1.0 / counter
    data[j][9] = np.mean(soft_calls['b'])
    data[j][10] = bins['i']*1.0 / counter
    data[j][11] = np.mean(soft_calls['i'])
    data_counter += 1
     

accuracy_by_filter_score( data, 'Accuracy of Context Chunk by Barcode -- Pseudo_Trained HMM' )
# Out:
# C:0.0		Assigned:0	Percentage:100.0%
# cscore:0.0 to 0.1	# of Events:44
# cscore:0.1 to 0.2	# of Events:2
# cscore:0.2 to 0.3	# of Events:2
# cscore:0.3 to 0.4	# of Events:1
# cscore:0.4 to 0.5	# of Events:5
# cscore:0.5 to 0.6	# of Events:5
# cscore:0.6 to 0.7	# of Events:11
# cscore:0.7 to 0.8	# of Events:11
# cscore:0.8 to 0.9	# of Events:27
# cscore:0.9 to 1.0	# of Events:21

# %% [markdown]
# ## Plot Functions

# %%
def accuracy_by_filter_score( data, title, sc=False ):
    
    # Convert Groups of arrays into lists of scores by csore.
    first, last, random = [], [], []
    hmm, best, ind = [], [], []
    sample_sizes = []
    
    for j in xrange(0,10):
            
            #trial = np.loadtxt( '../Data/Results/' + trial_name, delimiter = ',' )
            #accuracies = means[::2]
            #acc_std = stds[::2]
            #softcalls = means[1::2]
            #sc_std = stds[1::2]
            
            trial = data[j]
        
            accuracies = trial[::2]
            softcalls = trial[1::2]
            
            if sc:
                f,l,r,h,b,i = softcalls
            else:
                f,l,r,h,b,i = accuracies
            first.append( f ); last.append( l ); random.append( r )
            hmm.append( h ) ; best.append( b ); ind.append( i )
         
            #sample_sizes.append( trial_name.split('_')[3] )

    x = [ 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.0 ]
    plt.plot( x, first, label='first' )
    plt.plot( x, last, label='last' ) 
    plt.plot( x, random, label='random' )
    
    plt.plot( x, hmm, label='hmm' )
    plt.plot( x, best, label='best' )
    plt.plot( x, ind, label='ind' )
    
   # plt.title( trial_name.split('_')[0] + ' - ' + trial_name.split('_')[1] \
    #            + ' - ' + trial_name.split('_')[2], fontsize=14 )
    
    plt.title( title )
    plt.xlabel( 'Chunk Score Cutoff', fontsize=14 )
    plt.ylabel( 'Accuracy', fontsize=14 )
    plt.ylim( [0,1.0] )
    plt.legend(loc='lower left', bbox_to_anchor=(1.02, 0), borderaxespad=0, fontsize=14)
    plt.gca().invert_xaxis()
    plt.show()
